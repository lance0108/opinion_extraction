# %% [markdown]
# ## In this notebook, I try to group similar aspects. Similarity is measured using word embeddings. The grouping is done through clustering.

# %%
import pandas as pd
import gensim
import re
import numpy as np
from sklearn.cluster import KMeans, AgglomerativeClustering, Birch
# Out:
# C:\Users\Lance\Anaconda3\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
# Read previously extracted aspects
df_extract = pd.read_csv(r"extract1.csv")
print(len(df_extract))
df_extract.head()
# Out:
# 80942
#    doc_id      aspect      opinion     rel
# 0       1        odor         soft    amod
# 1       1  absorption        large    amod
# 2       1      brands  trustworthy   nsubj
# 3       1      brands          big    amod
# 4       1        work         fast  advmod

# %%
# Load pretrained word embeddings
en_model = gensim.models.KeyedVectors.load_word2vec_format(r'D:\nlp_resources\word2vec\GoogleNews-vectors-negative300.bin',
                                            binary=True)

# %%
print("Vocabulary size:", len(en_model.vocab))
print("Embedding dimension:", en_model.vector_size)
# Out:
# Vocabulary size: 3000000
# Embedding dimension: 300

# %%
# Check some examples
en_model.most_similar("odor")
# Out:
# [('odors', 0.8496967554092407),
#  ('smell', 0.7634782791137695),
#  ('stench', 0.6854438781738281),
#  ('odor_emanating', 0.6836669445037842),
#  ('unpleasant_odor', 0.6794102191925049),
#  ('noxious_odor', 0.6737198829650879),
#  ('foul_odor', 0.6714236736297607),
#  ('smells', 0.6644900441169739),
#  ('pungent_odor', 0.6629747152328491),
#  ('unpleasant_odors', 0.6477565765380859)]

# %%
df_extract[df_extract["aspect"]=="odor"]
# Out:
#        doc_id aspect        opinion     rel
# 0           1   odor           soft    amod
# 3244     1329   odor         strong    amod
# 3245     1329   odor        pungent    amod
# 6027     2434   odor        pungent    amod
# 7569     3127   odor         severe    amod
# 7570     3127   odor        pungent    amod
# 7571     3127   odor        similar    amod
# 12630    5188   odor          great    amod
# 18444    7704   odor  skin-friendly  advmod
# 23937   10087   odor     breathable   nsubj
# 26706   11337   odor        obvious    amod
# 28188   11911   odor        thinner    amod
# 30599   12881   odor            big    amod
# 37131   15673   odor          heavy   nsubj
# 40537   17085   odor          thick   nsubj
# 40538   17085   odor        urinary    amod
# 45753   19388   odor           good    amod
# 45961   19479   odor          heavy   nsubj
# 52475   22277   odor        pungent    amod
# 52942   22471   odor          clear    amod
# 53244   22606   odor        plastic    amod
# 60800   25919   odor         stinky    amod
# 62964   26832   odor        pungent    amod
# 63353   27009   odor           soft    amod
# 64344   27453   odor      generally  advmod
# 65267   27854   odor         strong    amod
# 65623   28007   odor         slight    amod
# 67322   28735   odor        pungent    amod
# 70307   30092   odor        urinary    amod
# 71115   30527   odor        pungent    amod
# 72969   31476   odor         little    amod
# 73053   31512   odor        pungent    amod
# 73695   31812   odor         always  advmod
# 75383   32806   odor         slight    amod
# 78007   34380   odor            wet   nsubj
# 79990   35473   odor         little    amod
# 80417   35705   odor         strong    amod

# %%
df_extract[df_extract["aspect"]=="odors"]
# Out:
#        doc_id aspect  opinion   rel
# 25319   10728  odors  serious  amod
# 37900   15997  odors      few  amod
# 72008   30987  odors  pungent  amod

# %%
df_extract[df_extract["aspect"]=="smell"]
# Out:
#        doc_id aspect     opinion     rel
# 1101      434  smell        good    amod
# 1197      466  smell      little    amod
# 1373      527  smell         bad    amod
# 1657      666  smell         red   nsubj
# 1658      666  smell     pungent    amod
# 2504     1021  smell         wet   nsubj
# 2821     1166  smell       great    amod
# 2839     1175  smell         big    amod
# 2840     1175  smell     pungent    amod
# 2879     1188  smell        just  advmod
# 2880     1188  smell      little    amod
# 3251     1331  smell         bad    amod
# 3292     1352  smell     strange    amod
# 3644     1486  smell      strong    amod
# 3649     1486  smell        full   nsubj
# 3677     1496  smell     pungent    amod
# 3744     1519  smell  definitely  advmod
# 3746     1519  smell        open    amod
# 3845     1561  smell     strange    amod
# 4475     1785  smell     pungent    amod
# 5513     2225  smell       large   nsubj
# 5591     2256  smell   alcoholic    amod
# 5911     2385  smell        good    amod
# 6388     2607  smell       heavy    amod
# 6447     2637  smell        good    amod
# 6448     2637  smell        soft    amod
# 6602     2701  smell         big    amod
# 6603     2701  smell     pungent    amod
# 6735     2751  smell      little    amod
# 6736     2751  smell      little    amod
# ...       ...    ...         ...     ...
# 72737   31378  smell     pungent    amod
# 72980   31481  smell        also  advmod
# 73045   31509  smell     pungent    amod
# 73055   31512  smell         big   nsubj
# 73163   31562  smell     serious    amod
# 73164   31562  smell     thinner    amod
# 73403   31679  smell       heavy    amod
# 73450   31701  smell       great    amod
# 73611   31763  smell     strange    amod
# 74069   32003  smell        good   nsubj
# 75304   32760  smell     pungent    amod
# 75442   32838  smell        much    amod
# 76038   33236  smell     pungent    amod
# 76361   33424  smell     strange    amod
# 76398   33452  smell       small   nsubj
# 76636   33598  smell     strange    amod
# 76673   33626  smell       small   nsubj
# 76868   33740  smell     pungent    amod
# 78897   34886  smell     obvious    amod
# 79567   35246  smell       clear    amod
# 79568   35246  smell        open    amod
# 79569   35246  smell     similar    amod
# 80015   35483  smell       heavy    amod
# 80017   35483  smell       large   nsubj
# 80469   35737  smell        good   nsubj
# 80488   35745  smell     useless   nsubj
# 80585   35807  smell        open    amod
# 80613   35820  smell     genuine    amod
# 80614   35820  smell        easy    amod
# 80848   35948  smell     strange    amod
#
# [375 rows x 4 columns]

# %%
emb_vocab = set(en_model.vocab)

# %%
# Construct vocabulary
word_pattern = re.compile("^[a-z]{3,}$") # Filter out non-alphabetic words and words with less than 3 characters.
word2index = {}
index2word = {}
index = 0
for word in df_extract["aspect"].unique():
    if word_pattern.match(word) and word in emb_vocab:
        word2index[word] = index
        index2word[index] = word
        index += 1
print(len(word2index))
# Out:
# 2021

# %%
# Construct feature matrix
word_vectors = []
for i in range(len(index2word)):
    vec = en_model.get_vector(index2word[i])
    word_vectors.append(vec)
word_vectors = np.array(word_vectors)
word_vectors.shape
# Out:
# (2021, 300)

# %%
# Export for visualization at https://projector.tensorflow.org/
with open(r"vocab.tsv", "w") as out_f:
    for i in range(len(index2word)):
        out_f.write(index2word[i])
        out_f.write("\n")
np.savetxt(r"vectors.tsv", word_vectors, delimiter="\t")

# %% [markdown]
# #### Clustering

# %%
birch =Birch(n_clusters=500)
labels = birch.fit_predict(word_vectors)

# %%
word_clusters = []
cluster_dict = {}
for i in range(len(index2word)):
    label = labels[i]
    word = index2word[i]
    word_clusters.append([label, word])
    cluster_dict[word] = label
df_word_clusters = pd.DataFrame(word_clusters, columns=["cluster", "word"])
df_word_clusters.head()
# Out:
#    cluster        word
# 0      368        odor
# 1       46  absorption
# 2        0      brands
# 3       98        work
# 4       56       price

# %%
df_cluster_sizes = df_word_clusters.groupby("cluster").count()
print(len(df_cluster_sizes[df_cluster_sizes["word"]>1]))
print(len(df_cluster_sizes[df_cluster_sizes["word"]>2]))
# Out:
# 449
# 320

# %%
eval_words = ["price", "absorption", "odor", "package", "brand", 
             "shipping", "elasticity", "padding", "lining", "material"] 
for word in eval_words:
    c = cluster_dict[word]
    print(word, c)
    print(df_word_clusters[df_word_clusters["cluster"]==c]["word"].unique())
    print("-"*100)
# Out:
# price 56
# ['price' 'prices' 'cost' 'expense' 'spending' 'fee' 'costs']
# ----------------------------------------------------------------------------------------------------
# absorption 46
# ['absorption' 'enlargement' 'accumulation' 'agglomeration' 'shrinkage']
# ----------------------------------------------------------------------------------------------------
# odor 368
# ['odor' 'smell' 'scent' 'odors']
# ----------------------------------------------------------------------------------------------------
# package 253
# ['packs' 'package' 'packages' 'pack' 'kit' 'bundle']
# ----------------------------------------------------------------------------------------------------
# brand 0
# ['brands' 'product' 'brand' 'products' 'promotion' 'branding' 'marketing'
#  'promotions']
# ----------------------------------------------------------------------------------------------------
# shipping 27
# ['shipment' 'shipments' 'shipping' 'ship' 'port']
# ----------------------------------------------------------------------------------------------------
# elasticity 39
# ['softness' 'elasticity' 'fullness']
# ----------------------------------------------------------------------------------------------------
# padding 97
# ['padding' 'liner' 'wadding' 'apron' 'pad' 'wings' 'hanger']
# ----------------------------------------------------------------------------------------------------
# lining 32
# ['packing' 'lining' 'checking' 'pilling' 'filling' 'check' 'throwing'
#  'handling' 'stuffing' 'loading']
# ----------------------------------------------------------------------------------------------------
# material 174
# ['material' 'materials' 'arrangements' 'structures' 'structure']
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Classify sentiment of opinion pairs

# %%
from pycorenlp import StanfordCoreNLP
# need to setup the CoreNLP server first
stanford = StanfordCoreNLP('http://localhost:9000')

# %%
def get_sentiment(text):
    results = stanford.annotate(text, 
                                properties={'annotators': 'sentiment',
                                            'outputFormat': 'json','timeout': '5000'})
    return results["sentences"][0]["sentiment"]

# %%
df_extract["cluster"] = df_extract["aspect"].apply(lambda x: cluster_dict.get(x, -1))
df_extract["pair"] = df_extract["opinion"] + " " + df_extract["aspect"]
df_extract["sentiment"] = df_extract["pair"].apply(get_sentiment)

# %%
df_extract["sentiment"].value_counts()
# Out:
# Neutral         49283
# Positive        26108
# Negative         5463
# Verypositive       54
# Verynegative       34
# Name: sentiment, dtype: int64

# %%
def replace_sentiment(s):
    if s == "Verypositive":
        return "Positive"
    if s == "Verynegative":
        return "Negative"
    return s
df_extract["sentiment2"] = df_extract["sentiment"].apply(replace_sentiment)
df_extract["sentiment2"].value_counts()
# Out:
# Neutral     49283
# Positive    26162
# Negative     5497
# Name: sentiment2, dtype: int64

# %% [markdown]
# ## Summarize opinion by brand

# %%
df_reviews = pd.read_csv(r"C:\Dropbox\_projects\PG\ds-nlp-interview-question_v2.csv")
df_reviews["id"] = list(range(len(df_reviews)))
df_reviews.head(2)
# Out:
#                                       REVIEW_TEXT_CN  \
# 0                                    花王的确实不错，一直用这个牌子
# 1  哈哈哈哈，真心不错的啊。没有异味，非常非常的柔软，吸收量很大，并且不起球，大品牌值得信赖，物...
#
#                                       REVIEW_TEXT_EN ONLINE_STORE    BRAND  \
# 0          Kao is really good, always use this brand        tmall  Merries
# 1  Hahahaha, really good. No odor, very very soft...       suning  Huggies
#
#    YEAR  MONTH  id
# 0  2016     11   0
# 1  2017      1   1

# %%
df_reviews["BRAND"].value_counts()
# Out:
# Huggies    13339
# Pampers    11351
# Merries    11310
# Name: BRAND, dtype: int64

# %%
brand_dict = {}
for i, row in df_reviews.iterrows():
    brand_dict[row["id"]] = row["BRAND"]

# %%
df_extract["brand"] = df_extract["doc_id"].apply(lambda x: brand_dict[x])
df_extract.head()
# Out:
#    doc_id      aspect      opinion     rel    brand  cluster  \
# 0       1        odor         soft    amod  Huggies      368
# 1       1  absorption        large    amod  Huggies       46
# 2       1      brands  trustworthy   nsubj  Huggies        0
# 3       1      brands          big    amod  Huggies        0
# 4       1        work         fast  advmod  Huggies       98
#
#                  pair sentiment sentiment2
# 0           soft odor   Neutral    Neutral
# 1    large absorption   Neutral    Neutral
# 2  trustworthy brands   Neutral    Neutral
# 3          big brands   Neutral    Neutral
# 4           fast work   Neutral    Neutral

# %%
brands = df_extract["brand"].unique()

# %%
eval_words = ["price", "absorption", "odor", "package", "brand", 
             "shipping", "elasticity", "padding", "lining", "material"] 
for word in eval_words:
    c = cluster_dict[word]
    print("Query word:",word, "\tWord cluster:", c)
    print("Aspects:", df_word_clusters[df_word_clusters["cluster"]==c]["word"].unique())
    for sentiment in ["Positive", "Neutral", "Negative"]:
        df_temp = df_extract[(df_extract["cluster"]==c)&(df_extract["sentiment2"]==sentiment)]
        df_crosstab = pd.crosstab(df_temp["pair"], df_temp["brand"])
        df_crosstab["Total"] = df_crosstab.sum(axis=1)
        df_crosstab = df_crosstab.sort_values("Total", ascending=False)
        print("\n*"+sentiment+"*"+"-"*40)
        print(df_crosstab[:5])
    print("="*100)
# Out:
# Query word: price 	Word cluster: 56
# Aspects: ['price' 'prices' 'cost' 'expense' 'spending' 'fee' 'costs']
#
# *Positive*----------------------------------------
# brand             Huggies  Merries  Pampers  Total
# pair
# affordable price       92       51       71    214
# good price             64       66       73    203
# cheaper price          59       51       54    164
# expensive price        58       47       48    153
# high price             61       31       55    147
#
# *Neutral*----------------------------------------
# brand              Huggies  Merries  Pampers  Total
# pair
# high cost                4        5        7     16
# better price             5        4        2     11
# affordable prices        2        3        0      5
# high prices              3        2        0      5
# curious price            3        0        0      3
#
# *Negative*----------------------------------------
# brand         Huggies  Merries  Pampers  Total
# pair
# cheap price       251      142      261    654
# low price          21       16       22     59
# bad price          10        5       10     25
# cheap prices        0        1        6      7
# worse price         5        0        0      5
# ====================================================================================================
# Query word: absorption 	Word cluster: 46
# Aspects: ['absorption' 'enlargement' 'accumulation' 'agglomeration' 'shrinkage']
#
# *Positive*----------------------------------------
# brand               Huggies  Merries  Pampers  Total
# pair
# strong absorption       323      244      317    884
# good absorption         250      268      265    783
# great absorption          1        3        1      5
# genuine absorption        0        3        1      4
# best absorption           0        3        0      3
#
# *Neutral*----------------------------------------
# brand             Huggies  Merries  Pampers  Total
# pair
# soft absorption        15       17       21     53
# large absorption       12       10        6     28
# thin absorption         8        2        9     19
# ok absorption           6        3        9     18
# easy absorption        11        4        3     18
#
# *Negative*----------------------------------------
# brand              Huggies  Merries  Pampers  Total
# pair
# poor absorption         18       20       25     63
# bad absorption          18        7        8     33
# worse absorption         4        7        0     11
# uneven absorption        2        1        3      6
# cheap absorption         1        1        1      3
# ====================================================================================================
# Query word: odor 	Word cluster: 368
# Aspects: ['odor' 'smell' 'scent' 'odors']
#
# *Positive*----------------------------------------
# brand          Huggies  Merries  Pampers  Total
# pair
# strong smell         1        4        8     13
# good smell           3        4        4     11
# great smell          0        2        3      5
# strong odor          1        0        2      3
# genuine smell        2        0        0      2
#
# *Neutral*----------------------------------------
# brand          Huggies  Merries  Pampers  Total
# pair
# pungent smell       13       29       41     83
# big smell            5        7       32     44
# strange smell        4       11       11     26
# little smell         5        5       10     20
# heavy smell          3        5       11     19
#
# *Negative*----------------------------------------
# brand             Huggies  Merries  Pampers  Total
# pair
# bad smell               3        3       12     18
# unpleasant smell        3        3        5     11
# cheap smell             0        0        1      1
# obvious odor            0        0        1      1
# so-called smell         0        0        1      1
# ====================================================================================================
# Query word: package 	Word cluster: 253
# Aspects: ['packs' 'package' 'packages' 'pack' 'kit' 'bundle']
#
# *Positive*----------------------------------------
# brand             Huggies  Merries  Pampers  Total
# pair
# good package           17       21       18     56
# new package            17       10       12     39
# big package             9        9       13     31
# large package           5        4        9     18
# complete package        5        5        2     12
#
# *Neutral*----------------------------------------
# brand           Huggies  Merries  Pampers  Total
# pair
# small package        17        9       18     44
# few packs             6       13        4     23
# intact package        1        3        6     10
# first package         3        5        2     10
# second pack           4        6        0     10
#
# *Negative*----------------------------------------
# brand           Huggies  Merries  Pampers  Total
# pair
# dirty package         1        3        3      7
# rotten package        3        4        0      7
# fake package          0        6        0      6
# thin package          3        2        0      5
# bad package           1        2        0      3
# ====================================================================================================
# Query word: brand 	Word cluster: 0
# Aspects: ['brands' 'product' 'brand' 'products' 'promotion' 'branding' 'marketing'
#  'promotions']
#
# *Positive*----------------------------------------
# brand            Huggies  Merries  Pampers  Total
# pair
# good brand           126      101      117    344
# good product         102       69       77    248
# good products         30       32       39    101
# genuine brand         10       18       19     47
# genuine product       15       12        5     32
#
# *Neutral*----------------------------------------
# brand               Huggies  Merries  Pampers  Total
# pair
# big brand               386      333      484   1203
# other brands            194      144      127    465
# big brands               98       87      158    343
# trustworthy brand        63       70       96    229
# trustworthy brands       31       25       49    105
#
# *Negative*----------------------------------------
# brand         Huggies  Merries  Pampers  Total
# pair
# bad brand          14        3       12     29
# cheap brands        7        4       16     27
# cheap brand         4        2       17     23
# bad product         5        2        7     14
# fake product        1        5        3      9
# ====================================================================================================
# Query word: shipping 	Word cluster: 27
# Aspects: ['shipment' 'shipments' 'shipping' 'ship' 'port']
#
# *Positive*----------------------------------------
# brand          Huggies  Merries  Total
# pair
# cute ship            0        1      1
# good ship            0        1      1
# good shipping        1        0      1
#
# *Neutral*----------------------------------------
# brand           Huggies  Merries  Pampers  Total
# pair
# fast shipping         0        3        0      3
# fast shipment         2        0        0      2
# fast shipments        0        2        0      2
# free shipping         1        1        0      2
# slow shipment         1        0        1      2
#
# *Negative*----------------------------------------
# brand                Huggies  Merries  Total
# pair
# disgusting shipment        1        0      1
# quickly ship               0        1      1
# ====================================================================================================
# Query word: elasticity 	Word cluster: 39
# Aspects: ['softness' 'elasticity' 'fullness']
#
# *Positive*----------------------------------------
# brand             Huggies  Merries  Pampers  Total
# pair
# good softness          16        8        5     29
# good elasticity         4        3       10     17
# fine softness           0        0        1      1
# genuine softness        0        1        0      1
# great elasticity        1        0        0      1
#
# *Neutral*----------------------------------------
# brand               Huggies  Merries  Pampers  Total
# pair
# ok softness               6        2        5     13
# previous softness         2        2        0      4
# better softness           4        0        0      4
# different softness        1        0        2      3
# double elasticity         0        0        3      3
#
# *Negative*----------------------------------------
# brand            Huggies  Merries  Pampers  Total
# pair
# bad softness           1        0        1      2
# weak elasticity        0        0        1      1
# wet fullness           0        1        0      1
# worse softness         0        0        1      1
# ====================================================================================================
# Query word: padding 	Word cluster: 97
# Aspects: ['padding' 'liner' 'wadding' 'apron' 'pad' 'wings' 'hanger']
#
# *Positive*----------------------------------------
# brand     Huggies  Total
# pair
# good pad        1      1
#
# *Neutral*----------------------------------------
# brand             Huggies  Merries  Pampers  Total
# pair
# broken wadding          0        0        1      1
# dirty pad               1        0        0      1
# free wadding            0        1        0      1
# inner liner             1        0        0      1
# leak-proof wings        1        0        0      1
#
# *Negative*----------------------------------------
# Empty DataFrame
# Columns: [Total]
# Index: []
# ====================================================================================================
# Query word: lining 	Word cluster: 32
# Aspects: ['packing' 'lining' 'checking' 'pilling' 'filling' 'check' 'throwing'
#  'handling' 'stuffing' 'loading']
#
# *Positive*----------------------------------------
# brand               Huggies  Merries  Pampers  Total
# pair
# good packing             36       19       30     85
# powerful pilling          1        1        1      3
# delicious stuffing        1        0        1      2
# genuine checking          1        0        0      1
# right packing             1        0        0      1
#
# *Neutral*----------------------------------------
# brand              Huggies  Merries  Pampers  Total
# pair
# ordinary stuffing        0        0        2      2
# little pilling           2        0        0      2
# tight packing            2        0        0      2
# simple packing           1        0        1      2
# new packing              1        0        1      2
#
# *Negative*----------------------------------------
# brand                   Huggies  Merries  Pampers  Total
# pair
# bad packing                   2        0        1      3
# cheap packing                 0        1        0      1
# disappointing handling        1        0        0      1
# ====================================================================================================
# Query word: material 	Word cluster: 174
# Aspects: ['material' 'materials' 'arrangements' 'structures' 'structure']
#
# *Positive*----------------------------------------
# brand                  Huggies  Merries  Pampers  Total
# pair
# good material                8        3        9     20
# good materials               2        0        1      3
# comfortable material         1        1        0      2
# comfortable materials        1        0        0      1
#
# *Neutral*----------------------------------------
# brand                     Huggies  Merries  Pampers  Total
# pair
# soft material                   9       10        6     25
# raw materials                   1        1        5      7
# different material              3        4        0      7
# water-absorbing material        1        0        4      5
# absorbent material              1        0        1      2
#
# *Negative*----------------------------------------
# brand           Huggies  Merries  Pampers  Total
# pair
# poor material         2        1        1      4
# poor materials        0        1        1      2
# worse material        1        0        1      2
# bad material          0        1        0      1
# ====================================================================================================

# %% [markdown]
# It seems that Pampers has a stronger smell.

# %%
df_extract.to_csv(r"extract1_clustered.csv", index=False)
